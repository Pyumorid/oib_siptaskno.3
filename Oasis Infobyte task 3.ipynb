# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com//amankharwal//Website-data//master//CarPrice.csv')

# %%
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# 0          two  convertible        rwd          front       88.6  ...
# 1          two  convertible        rwd          front       88.6  ...
# 2          two    hatchback        rwd          front       94.5  ...
# 3         four        sedan        fwd          front       99.8  ...
# 4         four        sedan        4wd          front       99.4  ...
# ..         ...          ...        ...            ...        ...  ...
# 200       four        sedan        rwd          front      109.1  ...
# 201       four        sedan        rwd          front      109.1  ...
# 202       four        sedan        rwd          front      109.1  ...
# 203       four        sedan        rwd          front      109.1  ...
# 204       four        sedan        rwd          front      109.1  ...
#
#      enginesize  fuelsystem  boreratio  stroke compressionratio horsepower  \
# 0           130        mpfi       3.47    2.68              9.0        111
# 1           130        mpfi       3.47    2.68              9.0        111
# 2           152        mpfi       2.68    3.47              9.0        154
# 3           109        mpfi       3.19    3.40             10.0        102
# 4           136        mpfi       3.19    3.40              8.0        115
# ..          ...         ...        ...     ...              ...        ...
# 200         141        mpfi       3.78    3.15              9.5        114
# 201         141        mpfi       3.78    3.15              8.7        160
# 202         173        mpfi       3.58    2.87              8.8        134
# 203         145         idi       3.01    3.40             23.0        106
# 204         141        mpfi       3.78    3.15              9.5        114
#
#      peakrpm citympg  highwaympg    price
# 0       5000      21          27  13495.0
# 1       5000      21          27  16500.0
# 2       5000      19          26  16500.0
# 3       5500      24          30  13950.0
# 4       5500      18          22  17450.0
# ..       ...     ...         ...      ...
# 200     5400      23          28  16845.0
# 201     5300      19          25  19045.0
# 202     5500      18          23  21485.0
# 203     4800      26          27  22470.0
# 204     5400      19          25  22625.0
#
# [205 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# car_ID              205
# symboling             6
# CarName             147
# fueltype              2
# aspiration            2
# doornumber            2
# carbody               5
# drivewheel            3
# enginelocation        2
# wheelbase            53
# carlength            75
# carwidth             44
# carheight            49
# curbweight          171
# enginetype            7
# cylindernumber        7
# enginesize           44
# fuelsystem            8
# boreratio            38
# stroke               37
# compressionratio     32
# horsepower           59
# peakrpm              23
# citympg              29
# highwaympg           30
# price               189
# dtype: int64

# %%
df1=df.copy()

# %%
df1['CarName'].sample(5)
# Out:
# 45          isuzu D-Max V-Cross
# 11                     bmw 320i
# 36          honda civic 1500 gl
# 68     buick century luxus (sw)
# 127             porsche cayenne
# Name: CarName, dtype: object

# %%
df1['car_ID']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 200    201
# 201    202
# 202    203
# 203    204
# 204    205
# Name: car_ID, Length: 205, dtype: int64

# %%
df1['fueltype']
# Out:
# 0         gas
# 1         gas
# 2         gas
# 3         gas
# 4         gas
#         ...
# 200       gas
# 201       gas
# 202       gas
# 203    diesel
# 204       gas
# Name: fueltype, Length: 205, dtype: object

# %%
df1['aspiration']
# Out:
# 0        std
# 1        std
# 2        std
# 3        std
# 4        std
#        ...
# 200      std
# 201    turbo
# 202      std
# 203    turbo
# 204    turbo
# Name: aspiration, Length: 205, dtype: object

# %%
df1['doornumber']
# Out:
# 0       two
# 1       two
# 2       two
# 3      four
# 4      four
#        ...
# 200    four
# 201    four
# 202    four
# 203    four
# 204    four
# Name: doornumber, Length: 205, dtype: object

# %%
df1['carbody']
# Out:
# 0      convertible
# 1      convertible
# 2        hatchback
# 3            sedan
# 4            sedan
#           ...
# 200          sedan
# 201          sedan
# 202          sedan
# 203          sedan
# 204          sedan
# Name: carbody, Length: 205, dtype: object

# %%
df1['price']
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, OneHotEncoder,StandardScaler,PowerTransformer, MinMaxScaler, RobustScaler
from sklearn.model_selection import KFold, cross_val_predict, train_test_split,GridSearchCV,cross_val_score

# %%
print( f"Skewness: {df1['price'].skew()}")
# Out:
# Skewness: 1.7776781560914454

# %%
numerical= df1.drop(['price'], axis=1).select_dtypes('number').columns

categorical = df1.select_dtypes('object').columns

print(f'Numerical Columns:  {df1[numerical].columns}')
print('\n')
print(f'Categorical Columns: {df1[categorical].columns}')
# Out:
# Numerical Columns:  Index(['car_ID', 'symboling', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginesize', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg'],
#       dtype='object')
#
#
# Categorical Columns: Index(['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber',
#        'fuelsystem'],
#       dtype='object')

# %%
df1['price'].describe()
# Out:
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 25%       7788.000000
# 50%      10295.000000
# 75%      16503.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
df1[numerical].describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg
# count  205.000000   205.000000  205.000000  205.000000
# mean   104.117073  5125.121951   25.219512   30.751220
# std     39.544167   476.985643    6.542142    6.886443
# min     48.000000  4150.000000   13.000000   16.000000
# 25%     70.000000  4800.000000   19.000000   25.000000
# 50%     95.000000  5200.000000   24.000000   30.000000
# 75%    116.000000  5500.000000   30.000000   34.000000
# max    288.000000  6600.000000   49.000000   54.000000

# %%
numerical1= df1.select_dtypes('number').columns


matrix = np.triu(df1[numerical1].corr())
fig, ax = plt.subplots(figsize=(14,10)) 
sns.heatmap (df1[numerical1].corr(), annot=True, fmt= '.2f', vmin=-1, vmax=1, center=0, cmap='coolwarm',mask=matrix, ax=ax);

# %%
df1[categorical].head()
# Out:
#                     CarName fueltype aspiration doornumber      carbody  \
# 0        alfa-romero giulia      gas        std        two  convertible
# 1       alfa-romero stelvio      gas        std        two  convertible
# 2  alfa-romero Quadrifoglio      gas        std        two    hatchback
# 3               audi 100 ls      gas        std       four        sedan
# 4                audi 100ls      gas        std       four        sedan
#
#   drivewheel enginelocation enginetype cylindernumber fuelsystem
# 0        rwd          front       dohc           four       mpfi
# 1        rwd          front       dohc           four       mpfi
# 2        rwd          front       ohcv            six       mpfi
# 3        fwd          front        ohc           four       mpfi
# 4        4wd          front        ohc           five       mpfi

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, mean_absolute_error, mean_squared_error, r2_score 
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

# %%
X=df.drop('CarName',axis=1)

# %%
X.head()
# Out:
#    car_ID  symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0       1          3      gas        std        two  convertible        rwd
# 1       2          3      gas        std        two  convertible        rwd
# 2       3          1      gas        std        two    hatchback        rwd
# 3       4          2      gas        std       four        sedan        fwd
# 4       5          2      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  ...  enginesize  fuelsystem  \
# 0          front       88.6      168.8  ...         130        mpfi
# 1          front       88.6      168.8  ...         130        mpfi
# 2          front       94.5      171.2  ...         152        mpfi
# 3          front       99.8      176.6  ...         109        mpfi
# 4          front       99.4      176.6  ...         136        mpfi
#
#    boreratio stroke compressionratio  horsepower peakrpm  citympg  highwaympg  \
# 0       3.47   2.68              9.0         111    5000       21          27
# 1       3.47   2.68              9.0         111    5000       21          27
# 2       2.68   3.47              9.0         154    5000       19          26
# 3       3.19   3.40             10.0         102    5500       24          30
# 4       3.19   3.40              8.0         115    5500       18          22
#
#      price
# 0  13495.0
# 1  16500.0
# 2  16500.0
# 3  13950.0
# 4  17450.0
#
# [5 rows x 25 columns]

# %%
Y=df['CarName']

# %%
Y
# Out:
# 0            alfa-romero giulia
# 1           alfa-romero stelvio
# 2      alfa-romero Quadrifoglio
# 3                   audi 100 ls
# 4                    audi 100ls
#                  ...
# 200             volvo 145e (sw)
# 201                 volvo 144ea
# 202                 volvo 244dl
# 203                   volvo 246
# 204                 volvo 264gl
# Name: CarName, Length: 205, dtype: object

# %%
X
# Out:
#      car_ID  symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0         1          3      gas        std        two  convertible        rwd
# 1         2          3      gas        std        two  convertible        rwd
# 2         3          1      gas        std        two    hatchback        rwd
# 3         4          2      gas        std       four        sedan        fwd
# 4         5          2      gas        std       four        sedan        4wd
# ..      ...        ...      ...        ...        ...          ...        ...
# 200     201         -1      gas        std       four        sedan        rwd
# 201     202         -1      gas      turbo       four        sedan        rwd
# 202     203         -1      gas        std       four        sedan        rwd
# 203     204         -1   diesel      turbo       four        sedan        rwd
# 204     205         -1      gas      turbo       four        sedan        rwd
#
#     enginelocation  wheelbase  carlength  ...  enginesize  fuelsystem  \
# 0            front       88.6      168.8  ...         130        mpfi
# 1            front       88.6      168.8  ...         130        mpfi
# 2            front       94.5      171.2  ...         152        mpfi
# 3            front       99.8      176.6  ...         109        mpfi
# 4            front       99.4      176.6  ...         136        mpfi
# ..             ...        ...        ...  ...         ...         ...
# 200          front      109.1      188.8  ...         141        mpfi
# 201          front      109.1      188.8  ...         141        mpfi
# 202          front      109.1      188.8  ...         173        mpfi
# 203          front      109.1      188.8  ...         145         idi
# 204          front      109.1      188.8  ...         141        mpfi
#
#      boreratio stroke compressionratio  horsepower peakrpm  citympg  \
# 0         3.47   2.68              9.0         111    5000       21
# 1         3.47   2.68              9.0         111    5000       21
# 2         2.68   3.47              9.0         154    5000       19
# 3         3.19   3.40             10.0         102    5500       24
# 4         3.19   3.40              8.0         115    5500       18
# ..         ...    ...              ...         ...     ...      ...
# 200       3.78   3.15              9.5         114    5400       23
# 201       3.78   3.15              8.7         160    5300       19
# 202       3.58   2.87              8.8         134    5500       18
# 203       3.01   3.40             23.0         106    4800       26
# 204       3.78   3.15              9.5         114    5400       19
#
#      highwaympg    price
# 0            27  13495.0
# 1            27  16500.0
# 2            26  16500.0
# 3            30  13950.0
# 4            22  17450.0
# ..          ...      ...
# 200          28  16845.0
# 201          25  19045.0
# 202          23  21485.0
# 203          27  22470.0
# 204          25  22625.0
#
# [205 rows x 25 columns]

# %%
#split the data into training and testing sets 
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.24,random_state=20)

# %%
X_train.head()
# Out:
#      car_ID  symboling fueltype aspiration doornumber    carbody drivewheel  \
# 80       81          3      gas      turbo        two  hatchback        fwd
# 201     202         -1      gas      turbo       four      sedan        rwd
# 90       91          1   diesel        std        two      sedan        fwd
# 184     185          2   diesel        std       four      sedan        fwd
# 21       22          1      gas        std        two  hatchback        fwd
#
#     enginelocation  wheelbase  carlength  ...  enginesize  fuelsystem  \
# 80           front       96.3      173.0  ...         110        spdi
# 201          front      109.1      188.8  ...         141        mpfi
# 90           front       94.5      165.3  ...         103         idi
# 184          front       97.3      171.7  ...          97         idi
# 21           front       93.7      157.3  ...          90        2bbl
#
#      boreratio stroke compressionratio  horsepower peakrpm  citympg  \
# 80        3.17   3.46             7.50         116    5500       23
# 201       3.78   3.15             8.70         160    5300       19
# 90        2.99   3.47            21.90          55    4800       45
# 184       3.01   3.40            23.00          52    4800       37
# 21        2.97   3.23             9.41          68    5500       37
#
#      highwaympg    price
# 80           30   9959.0
# 201          25  19045.0
# 90           50   7099.0
# 184          46   7995.0
# 21           41   5572.0
#
# [5 rows x 25 columns]

# %%
X_train.shape
# Out:
# (155, 25)

# %%
X_test.head
# Out:
# <bound method NDFrame.head of      car_ID  symboling fueltype aspiration doornumber      carbody drivewheel  \
# 5         6          2      gas        std        two        sedan        fwd
# 44       45          1      gas        std        two        sedan        fwd
# 155     156          0      gas        std       four        wagon        4wd
# 129     130          1      gas        std        two    hatchback        rwd
# 152     153          1      gas        std       four    hatchback        fwd
# 192     193          0   diesel      turbo       four        sedan        fwd
# 53       54          1      gas        std       four        sedan        fwd
# 149     150          0      gas      turbo       four        wagon        4wd
# 111     112          0      gas        std       four        sedan        rwd
# 135     136          2      gas        std       four        sedan        fwd
# 20       21          0      gas        std       four        sedan        fwd
# 166     167          1      gas        std        two    hatchback        rwd
# 13       14          0      gas        std       four        sedan        rwd
# 89       90          1      gas        std        two        sedan        fwd
# 140     141          2      gas        std        two    hatchback        4wd
# 121     122          1      gas        std       four        sedan        fwd
# 1         2          3      gas        std        two  convertible        rwd
# 92       93          1      gas        std       four        sedan        fwd
# 62       63          0      gas        std       four        sedan        fwd
# 200     201         -1      gas        std       four        sedan        rwd
# 59       60          1      gas        std        two    hatchback        fwd
# 154     155          0      gas        std       four        wagon        4wd
# 67       68         -1   diesel      turbo       four        sedan        rwd
# 104     105          3      gas        std        two    hatchback        rwd
# 117     118          0      gas      turbo       four        sedan        rwd
# 46       47          2      gas        std        two    hatchback        rwd
# 122     123          1      gas        std       four        sedan        fwd
# 143     144          0      gas        std       four        sedan        fwd
# 180     181         -1      gas        std       four        sedan        rwd
# 34       35          1      gas        std        two    hatchback        fwd
# 28       29         -1      gas        std       four        wagon        fwd
# 151     152          1      gas        std        two    hatchback        fwd
# 182     183          2   diesel        std        two        sedan        fwd
# 147     148          0      gas        std       four        wagon        fwd
# 159     160          0   diesel        std       four    hatchback        fwd
# 188     189          2      gas        std       four        sedan        fwd
# 86       87          1      gas        std       four        sedan        fwd
# 103     104          0      gas        std       four        sedan        fwd
# 119     120          1      gas      turbo        two    hatchback        fwd
# 85       86          1      gas        std       four        sedan        fwd
# 187     188          2   diesel      turbo       four        sedan        fwd
# 91       92          1      gas        std        two        sedan        fwd
# 153     154          0      gas        std       four        wagon        fwd
# 171     172          2      gas        std        two    hatchback        rwd
# 77       78          2      gas        std        two    hatchback        fwd
# 113     114          0      gas        std       four        wagon        rwd
# 197     198         -1      gas        std       four        wagon        rwd
# 64       65          0      gas        std       four    hatchback        fwd
# 181     182         -1      gas        std       four        wagon        rwd
# 202     203         -1      gas        std       four        sedan        rwd
#
#     enginelocation  wheelbase  carlength  ...  enginesize  fuelsystem  \
# 5            front       99.8      177.3  ...         136        mpfi
# 44           front       94.5      155.9  ...          90        2bbl
# 155          front       95.7      169.7  ...          92        2bbl
# 129          front       98.4      175.7  ...         203        mpfi
# 152          front       95.7      158.7  ...          92        2bbl
# 192          front      100.4      180.2  ...          97         idi
# 53           front       93.1      166.8  ...          91        2bbl
# 149          front       96.9      173.6  ...         108        mpfi
# 111          front      107.9      186.7  ...         120        mpfi
# 135          front       99.1      186.6  ...         121        mpfi
# 20           front       94.5      158.8  ...          90        2bbl
# 166          front       94.5      168.7  ...          98        mpfi
# 13           front      101.2      176.8  ...         164        mpfi
# 89           front       94.5      165.3  ...          97        2bbl
# 140          front       93.3      157.3  ...         108        2bbl
# 121          front       93.7      167.3  ...          90        2bbl
# 1            front       88.6      168.8  ...         130        mpfi
# 92           front       94.5      165.3  ...          97        2bbl
# 62           front       98.8      177.8  ...         122        2bbl
# 200          front      109.1      188.8  ...         141        mpfi
# 59           front       98.8      177.8  ...         122        2bbl
# 154          front       95.7      169.7  ...          92        2bbl
# 67           front      110.0      190.9  ...         183         idi
# 104          front       91.3      170.7  ...         181        mpfi
# 117          front      108.0      186.7  ...         134        mpfi
# 46           front       96.0      172.6  ...         119        spfi
# 122          front       93.7      167.3  ...          98        2bbl
# 143          front       97.2      172.0  ...         108        mpfi
# 180          front      104.5      187.8  ...         171        mpfi
# 34           front       93.7      150.0  ...          92        1bbl
# 28           front      103.3      174.6  ...         122        2bbl
# 151          front       95.7      158.7  ...          92        2bbl
# 182          front       97.3      171.7  ...          97         idi
# 147          front       97.0      173.5  ...         108        mpfi
# 159          front       95.7      166.3  ...         110         idi
# 188          front       97.3      171.7  ...         109        mpfi
# 86           front       96.3      172.4  ...         122        2bbl
# 103          front      100.4      184.6  ...         181        mpfi
# 119          front       93.7      157.3  ...          98        spdi
# 85           front       96.3      172.4  ...         122        2bbl
# 187          front       97.3      171.7  ...          97         idi
# 91           front       94.5      165.3  ...          97        2bbl
# 153          front       95.7      169.7  ...          92        2bbl
# 171          front       98.4      176.2  ...         146        mpfi
# 77           front       93.7      157.3  ...          92        2bbl
# 113          front      114.2      198.9  ...         120        mpfi
# 197          front      104.3      188.8  ...         141        mpfi
# 64           front       98.8      177.8  ...         122        2bbl
# 181          front      104.5      187.8  ...         161        mpfi
# 202          front      109.1      188.8  ...         173        mpfi
#
#      boreratio stroke compressionratio  horsepower peakrpm  citympg  \
# 5         3.19   3.40              8.5         110    5500       19
# 44        3.03   3.11              9.6          70    5400       38
# 155       3.05   3.03              9.0          62    4800       27
# 129       3.94   3.11             10.0         288    5750       17
# 152       3.05   3.03              9.0          62    4800       31
# 192       3.01   3.40             23.0          68    4500       33
# 53        3.03   3.15              9.0          68    5000       31
# 149       3.62   2.64              7.7         111    4800       23
# 111       3.46   2.19              8.4          95    5000       19
# 135       3.54   3.07              9.3         110    5250       21
# 20        3.03   3.11              9.6          70    5400       38
# 166       3.24   3.08              9.4         112    6600       26
# 13        3.31   3.19              9.0         121    4250       21
# 89        3.15   3.29              9.4          69    5200       31
# 140       3.62   2.64              8.7          73    4400       26
# 121       2.97   3.23              9.4          68    5500       31
# 1         3.47   2.68              9.0         111    5000       21
# 92        3.15   3.29              9.4          69    5200       31
# 62        3.39   3.39              8.6          84    4800       26
# 200       3.78   3.15              9.5         114    5400       23
# 59        3.39   3.39              8.6          84    4800       26
# 154       3.05   3.03              9.0          62    4800       27
# 67        3.58   3.64             21.5         123    4350       22
# 104       3.43   3.27              9.0         160    5200       19
# 117       3.61   3.21              7.0         142    5600       18
# 46        3.43   3.23              9.2          90    5000       24
# 122       2.97   3.23              9.4          68    5500       31
# 143       3.62   2.64              9.0          94    5200       26
# 180       3.27   3.35              9.2         156    5200       20
# 34        2.91   3.41              9.2          76    6000       30
# 28        3.34   3.46              8.5          88    5000       24
# 151       3.05   3.03              9.0          62    4800       31
# 182       3.01   3.40             23.0          52    4800       37
# 147       3.62   2.64              9.0          94    5200       25
# 159       3.27   3.35             22.5          56    4500       38
# 188       3.19   3.40             10.0         100    5500       26
# 86        3.35   3.46              8.5          88    5000       25
# 103       3.43   3.27              9.0         152    5200       19
# 119       3.03   3.39              7.6         102    5500       24
# 85        3.35   3.46              8.5          88    5000       25
# 187       3.01   3.40             23.0          68    4500       37
# 91        3.15   3.29              9.4          69    5200       31
# 153       3.05   3.03              9.0          62    4800       31
# 171       3.62   3.50              9.3         116    4800       24
# 77        2.97   3.23              9.4          68    5500       31
# 113       3.46   2.19              8.4          95    5000       19
# 197       3.78   3.15              9.5         114    5400       24
# 64        3.39   3.39              8.6          84    4800       26
# 181       3.27   3.35              9.2         156    5200       19
# 202       3.58   2.87              8.8         134    5500       18
#
#      highwaympg    price
# 5            25  15250.0
# 44           43   8916.5
# 155          32   8778.0
# 129          28  31400.5
# 152          38   6488.0
# 192          38  13845.0
# 53           38   6695.0
# 149          23  11694.0
# 111          24  15580.0
# 135          28  15510.0
# 20           43   6575.0
# 166          29   9538.0
# 13           28  21105.0
# 89           37   5499.0
# 140          31   7603.0
# 121          38   6692.0
# 1            27  16500.0
# 92           37   6849.0
# 62           32  10245.0
# 200          28  16845.0
# 59           32   8845.0
# 154          32   7898.0
# 67           25  25552.0
# 104          25  17199.0
# 117          24  18150.0
# 46           29  11048.0
# 122          38   7609.0
# 143          32   9960.0
# 180          24  15690.0
# 34           34   7129.0
# 28           30   8921.0
# 151          38   6338.0
# 182          46   7775.0
# 147          31  10198.0
# 159          47   7788.0
# 188          32   9995.0
# 86           32   8189.0
# 103          25  13499.0
# 119          30   7957.0
# 85           32   6989.0
# 187          42   9495.0
# 91           37   6649.0
# 153          37   6918.0
# 171          30  11549.0
# 77           38   6189.0
# 113          24  16695.0
# 197          28  16515.0
# 64           32  11245.0
# 181          24  15750.0
# 202          23  21485.0
#
# [50 rows x 25 columns]>

# %%
X_test.shape
# Out:
# (50, 25)

# %%
Y_train.head()
# Out:
# 80     mitsubishi mirage g4
# 201             volvo 144ea
# 90              nissan gt-r
# 184    volkswagen model 111
# 21            dodge rampage
# Name: CarName, dtype: object

# %%
Y_train.shape
# Out:
# (155,)

# %%
Y_test.head()
# Out:
# 5                 audi fox
# 44            isuzu D-Max
# 155          toyota carina
# 129        porsche cayenne
# 152    toyota corolla 1200
# Name: CarName, dtype: object

# %%
Y_test.shape
# Out:
# (50,)

# %%
model=LogisticRegression()

# %%
model.fit=(X_train,Y_train)

# %%
model.fit=(X_test,Y_test)
